# %% [markdown]
# # Régression Linéaire Multiple pour prédire le prix d'un bien en fonction de ses caractéristiques

# %% [markdown]
# ## 1- Préparation du dataset

# %% [markdown]
# ###  a. Chargement du dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split


#chargement du dataset:
dataset = pd.read_csv('kc_house_data.csv')
dataset
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
dataset.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# ### b- Suppression des colonnes inutils et des valeurs nulles

# %%
#suppression des colonnes date et id:

dataset = dataset.drop(['id', 'date'], axis=1)
dataset
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21608           0     0          3      8        1530              0
# 21609           0     0          3      8        2310              0
# 21610           0     0          3      7        1020              0
# 21611           0     0          3      8        1600              0
# 21612           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 19 columns]

# %%
#chercher les valeurs nulls:

dataset.isnull().values.sum()
# Out:
# 0

# %%
#suppression des valeurs nulls:
dataset.dropna(axis=0, how='any', inplace=True)
dataset.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# ### c- Séparation des colonnes en target et features

# %%
#séparation des variables "features" et "target":

features = dataset[dataset.iloc[:, 1:].columns.tolist()]
features
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 
# 3      604000.0
# 4      510000.0
# ...         ...
# 21608  360000.0
# 21609  400000.0
# 21610  402101.0
# 21611  400000.0
# 21612  325000.0
#
# [21613 rows x 1 columns]

# %% [markdown]
# ### d- Division des features et target en jeu de test et jeu de d'entrainement

# %%
x_train, x_test, y_train, y_test =  train_test_split(features, target, test_size=0.2, random_state=42)

print('x_train shape  : ', x_train.shape)
print('x_test shape  : ', x_test.shape)
print('y_train shape  : ', y_train.shape)
print('y_test shape  : ', y_test.shape)
# Out:
# x_train shape  :  (17290, 18)
# x_test shape  :  (4323, 18)
# y_train shape  :  (17290, 1)
# y_test shape  :  (4323, 1)

# %%
x_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 6325          3       1.75         1780     13095     1.0           0     0
# 13473         2       1.00         1000      3700     1.0           0     0
# 17614         3       1.00         1080      7486     1.5           0     0
# 16970         3       2.25         2090      7500     1.0           0     0
# 20868         2       2.50         1741      1439     2.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 11964         3       1.50         1000      6914     1.0           0     0
# 21575         3       2.50         3087      5002     2.0           0     0
# 5390          3       2.50         2120      4780     2.0           0     0
# 860           1       0.75          380     15000     1.0           0     0
# 15795         4       2.50         3130      5999     2.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 6325           4      9        1780              0      1983             0
# 13473          3      6         800            200      1929             0
# 17614          3      6         990             90      1942             0
# 16970          4      7        1280            810      1977             0
# 20868          3      8        1446            295      2007             0
# ...          ...    ...         ...            ...       ...           ...
# 11964          3      7        1000              0      1947             0
# 21575          3      8        3087              0      2014             0
# 5390           3      7        2120              0      2004             0
# 860            3      5         380              0      1963             0
# 15795          3      7        3130              0      2006             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15
# 6325     98042  47.3670 -122.152           2750       13095
# 13473    98118  47.5520 -122.290           1270        5000
# 17614    98146  47.4838 -122.335           1170        7800
# 16970    98031  47.3951 -122.172           1800        7350
# 20868    98034  47.7043 -122.209           2090       10454
# ...        ...      ...      ...            ...         ...
# 11964    98125  47.7144 -122.319           1000        6947
# 21575    98023  47.2974 -122.349           2927        5183
# 5390     98053  47.6810 -122.032           1690        2650
# 860      98168  47.4810 -122.323           1170       15000
# 15795    98042  47.3837 -122.099           3020        5997
#
# [17290 rows x 18 columns]

# %%
x_train.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  17290.000000  17290.000000  17290.000000  1.729000e+04  17290.000000
# mean       3.368132      2.113794   2073.894910  1.479895e+04      1.499161
# std        0.931385      0.766790    907.297963  3.883925e+04      0.542819
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      1.500000   1430.000000  5.001250e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.600000e+03      1.500000
# 75%        4.000000      2.500000   2540.000000  1.060675e+04      2.000000
# max       33.000000      8.000000  12050.000000  1.164794e+06      3.500000
#
#          waterfront          view     condition         grade    sqft_above  \
# count  17290.000000  17290.000000  17290.000000  17290.000000  17290.000000
# mean       0.007172      0.233025      3.407577      7.653846   1785.962175
# std        0.084385      0.761749      0.651698      1.170355    821.626290
# min        0.000000      0.000000      1.000000      1.000000    290.000000
# 25%        0.000000      0.000000      3.000000      7.000000   1200.000000
# Out:
#           price
# 6325   325000.0
# 13473  257000.0
# 17614  228500.0
# 16970  288000.0
# 20868  479000.0
# ...         ...
# 11964  378000.0
# 21575  399950.0
# 5390   575000.0
# 860    245000.0
# 15795  315000.0
#
# [17290 rows x 1 columns]

# %%
y_test
# Out:
#            price
# 735     365000.0
# 2830    865000.0
# 4106   1038000.0
# 16218  1490000.0
# 19964   711000.0
# ...          ...
# 13674   338000.0
# 20377   673000.0
# 8805    285000.0
# 10168   605000.0
# 2522    356500.0
#
# [4323 rows x 1 columns]

# %% [markdown]
# ### e- Normalisation des features
# Normaliser les features pour qu'ils varient sur une même échelle. Il y a trois techniques pour la normalisation:<br>
# 1. La mise à l'échelle des caractéristiques consiste essentiellement à diviser chaque caractéristique positive par sa valeur maximale, ou plus généralement, à rééchelonner chaque caractéristique en utilisant la formule **(x-min)/(max-min)**, où x est la valeur de la caractéristique. Les deux méthodes normalisent les caractéristiques dans la plage de -1 à 1, la première méthode étant adaptée aux caractéristiques positives, et la seconde méthode étant applicable à toutes les caractéristiques.<br><br>
# 2. **La normalisation par la moyenne**, également appelée centration des données, est une technique de mise à l'échelle des caractéristiques. Elle consiste à soustraire la moyenne de chaque valeur de caractéristique, de sorte que les données aient une moyenne égale à zéro. Mathématiquement, cela peut être exprimé comme suit pour une caractéristique
#
#  $x_i := \dfrac{x_i - \mu_i}{max - min} $ <br> <br>
# 3. **La normalisation Z-score**, également appelée standardisation, est une méthode de mise à l'échelle des caractéristiques. Elle consiste à transformer les données de telle sorte qu'elles aient une moyenne de 0 et un écart type de 1. Mathématiquement, pour une caractéristique x, la normalisation Z-score est calculée comme suit :
#
# $$x^{(i)}_j = \dfrac{x^{(i)}_j - \mu_j}{\sigma_j} \tag{4}$$ <br>
#
# où $j$ séléctionne une caractéristique ou une colonne de la matrice $\mathbf{X}$. $µ_j$ est la moyenne de toutes les valeurs de la caractéristique (j) et $\sigma_j$ est la déviation standard de la caractéristique (j).
# $$
# \begin{align}
# \mu_j &= \frac{1}{m} \sum_{i=0}^{m-1} x^{(i)}_j \tag{5}\\
# \sigma^2_j &= \frac{1}{m} \sum_{i=0}^{m-1} (x^{(i)}_j - \mu_j)^2  \tag{6}
# \end{align}
# $$

# %%
def z_score_normalization(data):
    """
    Normalise les caractéristiques d'un ensemble de données en utilisant la méthode Z-score.

    Args:
    - data : un tableau NumPy contenant les données à normaliser. Chaque colonne représente une caractéristique.

    Returns:
    - data_normalized : le tableau NumPy contenant les données normalisées.
    - mean : le tableau NumPy contenant les moyennes de chaque caractéristique avant normalisation.
    - std : le tableau NumPy contenant les déviations standard de chaque caractéristique avant normalisation.
    """
    # Calcul des moyennes et des déviations standard de chaque caractéristique
    mean = np.mean(data, axis=0)
    std = np.std(data, axis=0)

    # Normalisation des données en utilisant la méthode Z-score
    data_normalized = (data - mean) / std

    return data_normalized, mean, std

# %%
x_train_norm, mean,std=z_score_normalization(x_train)
x_train_norm
#x_train_norm= (x_train - x_train.mean())/x_train.std()
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_l
# zipcode          1.296183e-13
# lat             -1.761052e-12
# long             7.111527e-12
# sqft_living15   -3.101433e-17
# sqft_lot15       2.298624e-17
# dtype: float64

# %%
x_train_norm.std()
# Out:
# bedrooms         1.000029
# bathrooms        1.000029
# sqft_living      1.000029
# sqft_lot         1.000029
# floors           1.000029
# waterfront       1.000029
# view             1.000029
# condition        1.000029
# grade            1.000029
# sqft_above       1.000029
# sqft_basement    1.000029
# yr_built         1.000029
# yr_renovated     1.000029
# zipcode          1.000029
# lat              1.000029
# long             1.000029
# sqft_living15    1.000029
# sqft_lot15       1.000029
# dtype: float64

# %%
mean
# Out:
# bedrooms             3.368132
# bathrooms            2.113794
# sqft_living       2073.894910
# sqft_lot         14798.947368
# floors               1.499161
# waterfront           0.007172
# view                 0.233025
# condition            3.407577
# grade                7.653846
# sqft_above        1785.962175
# sqft_basement      287.932736
# yr_built          1971.108329
# yr_renovated        83.003412
# zipcode          98077.974378
# lat                 47.560330
# long              -122.214139
# sqft_living15     1982.904569
# sqft_lot15       12725.059341
# dtype: float64

# %%
std
# Out:
# bedrooms             0.931358
# bathrooms            0.766768
# sqft_living        907.271725
# sqft_lot         38838.125328
# floors               0.542803
# waterfront           0.084382
# view                 0.761727
# condition            0.651679
# grade                1.170321
# sqft_above         821.602529
# sqft_basement      438.714422
# yr_built            29.434752
# yr_renovated       398.491726
# zipcode             53.324542
# lat                  0.138428
# long                 0.140494
# sqft_living15      681.212725
# sqft_lot15       27524.462286
# dtype: float64

# %%
# Normalization de x_test
#
x_test_norm= (x_test - mean)/std
x_test_norm
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot   floors  waterfront  \
# 735    0.678437   0.177636    -0.004293 -0.152066  0.92269   -0.084992
# 2830   1.752138   1.155768     0.910538 -0.207758 -0.91960   -0.084992
# 4106   0.678437   0.503680     1.869457 -0.100570  0.92269   -0.084992
# 16218 -0.395263   1.807856     2.740199 -0.004916  0.92269   -0.084992
# 19964 -0.395263   0.503680     0.524766 -0.242621  0.92269   -0.084992
# ...         ...        ...          ...       ...      ...         ...
# 13674 -0.395263  -0.474451    -0.908102 -0.182525 -0.91960   -0.084992
# 20377 -0.395263   0.829724     0.833383 -0.291027  0.92269   -0.084992
# 8805   0.678437   0.503680     0.396910 -0.267751  0.92269   -0.084992
# 10168  0.678437  -0.474451     0.194104 -0.120782 -0.91960   -0.084992
# 2522   0.678437   0.503680     0.546810 -0.085636  0.92269   -0.084992
#
#            view  condition     grade  sqft_above  sqft_basement  yr_built  \
# 735   -0.305917   0.909073  0.295777    0.345712      -0.656310  0.505921
# 2830  -0.305917   2.443571  0.295777    0.053600       1.782634  0.200160
# 4106   2.319696  -0.625426  2.859176    2.414839      -0.656310  0.879629
# 16218  2.319696  -0.625426  3.713643    3.376374      -0.656310  0.641815
# 19964 -0.305917  -0.625426  1.150243    0.929936      -0.656310  1.117443
# ...         ...        ...       ...         ...            ...       ...
# 13674 -0.305917   0.909073 -0.558690   -0.652338      -0.656310 -0.819043
# 20377 -0.305917  -0.625426  0.295777    1.270733      -0.656310  1.389231
# 8805  -0.305917  -0.625426  0.295777    0.788749      -0.656310  1.219364
# 10168 -0.305917   0.909073  0.295777    0.564796      -0.656310 -0.139574
# 2522  -0.305917  -0.625426  0.295777    0.954279      -0.656310  1.253337
#
#        yr_renovated   zipcode       lat      long  sqft_living15  sqft_lot15
# 735       -0.208294 -0.374581 -0.877926  0.371111       0.597604   -0.182567
# 2830      -0.208294  0.694345  0.852938 -0.504370       0.568245   -0.234049
# 4106      -0.208294 -1.349742  0.030850  0.605996       2.535325   -0.110449
# 16218     -0.208294 -0.824656  1.005364 -0.098659       3.034435    0.054531
# 19964     -0.208294 -0.487100  0.753969  0.933412       0.392088   -0.315176
# ...             ...       ...       ...       ...            ...         ...
# 13674     -0.208294  1.444469  1.459029 -0.732137      -0.943765   -0.182204
# 20377     -0.208294 -0.918421  0.001954  1.445888       0.259971   -0.335122
# 8805      -0.208294 -1.443508 -1.971636 -0.490134       0.662195   -0.302460
# 10168     -0.208294 -1.312236  0.230231  0.684291       0.098494   -0.108088
# 2522      -0.208294 -1.406001 -2.018592 -0.582665       0.656323   -0.244439
#
# [4323 rows x 18 columns]

# %% [markdown]
# ### 2- Construction de X, Theta et Y

# %%
#x train:
X_train_norm_1 = np.hstack((x_train_norm, np.ones((x_train.shape[0], 1))))
X_train_norm_1
# Out:
# array([[-0.39526335, -0.47445144, -0.32393262, ...,  1.12607326,
#          0.01344043,  1.        ],
#        [-1.46896378, -1.45258323, -1.18365301, ..., -1.04652268,
#         -0.28066159,  1.        ],
#        [-0.39526335, -1.45258323, -1.09547656, ..., -1.19331971,
#         -0.1789339 ,  1.        ],
#        ...,
#        [-0.39526335,  0.50368036,  0.05081729, ..., -0.42997519,
#         -0.36604019,  1.        ],
#        [-2.54266422, -1.77862716, -1.8670205 , ..., -1.19331971,
#          0.08265159,  1.        ],
#        [ 0.67843709,  0.50368036,  1.16404497, ...,  1.52242522,
#         -0.24443927,  1.        ]])

# %%
X_test_norm_1 = np.hstack((x_test_norm, np.ones((x_test.shape[0], 1))))
X_test_norm_1
# Out:
# array([[ 0.67843709,  0.17763643, -0.00429299, ...,  0.59760397,
#         -0.18256703,  1.        ],
#        [ 1.75213752,  1.15576822,  0.91053768, ...,  0.56824457,
#         -0.23404851,  1.        ],
#        [ 0.67843709,  0.50368036,  1.86945657, ...,  2.53532468,
#         -0.11044936,  1.        ],
#        ...,
#        [ 0.67843709,  0.50368036,  0.39690986, ...,  0.66219466,
#         -0.30246038,  1.        ],
#        [ 0.67843709, -0.47445144,  0.19410402, ...,  0.0984941 ,
#         -0.10808783,  1.        ],
#        [ 0.67843709,  0.50368036,  0.54680982, ...,  0.65632278,
#         -0.24443927,  1.        ]])

# %%
Y_train = y_train.values
Y_train
# Out:
# array([[325000.],
#        [257000.],
#        [228500.],
#        ...,
#        [575000.],
#        [245000.],
#        [315000.]])

# %%
Y_test = y_test.values
Y_test
# Out:
# array([[ 365000.],
#        [ 865000.],
#        [1038000.],
#        ...,
#        [ 285000.],
#        [ 605000.],
#        [ 356500.]])

# %%
#construction aléatoire de Theta initial:
np.random.seed(0)

theta = np.random.randn(X_train_norm_1.shape[1], 1)
theta
# Out:
# array([[ 1.76405235],
#        [ 0.40015721],
#        [ 0.97873798],
#        [ 2.2408932 ],
#        [ 1.86755799],
#        [-0.97727788],
#        [ 0.95008842],
#        [-0.15135721],
#        [-0.10321885],
#        [ 0.4105985 ],
#        [ 0.14404357],
#        [ 1.45427351],
#        [ 0.76103773],
#        [ 0.12167502],
#        [ 0.44386323],
#        [ 0.33367433],
#        [ 1.49407907],
#        [-0.20515826],
#        [ 0.3130677 ]])

# %% [markdown]
# ### 4- Définition et entraînemet du modèle

# %%
def model(X, theta): # définir le modèle
    return X.dot(theta)

def cost_function(X, y, theta): #définir la fonction coût
    m = len(y)
    return 1/(2*m) * np.sum((model(X, theta) - y)**2)

cost_function(X_train_norm_1, Y_train ,theta)
# Out:
# 209920064632.06253

# %%
# définir la fonction de gradient
def grad(X, y, theta):
    m = len(y)
    return 1/m * X.T.dot(model(X, theta) - y)
# Définir la descente de gradient
def gradient_descent(X, y, theta, learning_rate, n_iterations):

    cost_history = np.zeros(n_iterations) # création d'un tableau de stockage pour enregistrer l'évolution du Cout du modele

    for i in range(0, n_iterations):
        theta = theta - learning_rate * grad(X, y, theta) # mise a jour du parametre theta (formule du gradient descent)
        cost_history[i] = cost_function(X, y, theta) # on enregistre la valeur du Cout au tour i dans cost_history[i]

    return theta, cost_history

# %%
#entrainement:
theta_final, cost_h = gradient_descent(X_train_norm_1, Y_train, theta, learning_rate=0.1, n_iterations=1000)

theta_final
# Out:
# array([[-31978.5832531 ],
#        [ 34170.64736014],
#        [ 80144.58976744],
#        [  3450.66466968],
#        [  3801.31860151],
#        [ 47457.60400103],
#        [ 40859.88012288],
#        [ 15983.53630371],
#        [110674.78775156],
#        [ 74521.6005931 ],
#        [ 26179.43858929],
#        [-78907.76795809],
#        [  8135.46078291],
#        [-29448.64012696],
#        [ 82498.66056158],
#        [-27338.17338572],
#        [ 14451.47195045],
#        [ -8968.34710252],
#        [537768.04794713]])

# %% [markdown]
# #### courbe d'apprentissage

# %%
plt.plot(range(1000), cost_h)
plt.show()

# %%
# Evaluation du modèle
def coef_determination(y, pred):
    u = ((y - pred)**2).sum()
    v = ((y - y.mean())**2).sum()
    return 1 - u/v

coef_determination(Y_test, model(X_test_norm_1,theta_final))
# Out:
# 0.7011904448913122

# %% [markdown]
# #### Tester des prédictions

# %%
predictions=model(X_test_norm_1, theta_final)
predictions
# Out:
# array([[ 461209.94694899],
#        [ 752443.51008474],
#        [1238489.80206504],
#        ...,
#        [ 423101.46387778],
#        [ 617785.61418349],
#        [ 442344.46089286]])

# %%
print("Le prix prédit du premier bien du dataset de test est", predictions[0])
# Out:
# Le prix prédit du premier bien du dataset de test est [461209.94694899]

# %%
print("Le prix réel du premier bien du dataset de test est",Y_test[0])
# Out:
# Le prix réel du premier bien du dataset de test est [365000.]

# %%
print("La marge d'erreur commise est",model(X_test_norm_1, theta_final)[0]-Y_test[0])
# Out:
# La marge d'erreur commise est [96209.94694899]
